# %% [markdown]
# ### **Installations**

# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/Capstone/Crawling medium/scrape_all")

# %%
# !pip install fake-useragent

# %%
import pandas as pd
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
# from get_proxies import get_proxies
# from get_name import get_name
import requests
import os.path
from os import path
import calendar

# %% [markdown]
# ### **Functions to scrape**
# - ```get_name```: convert url to appropriate name for storage purposes
# - ```scraper```: tool to scrape with Medium publisher URL and the year you want to scrape, the scraper will crawl everyday in that year for 10 posts each.

# %%
def get_name(test_str):

    # initializing punctuations string  
    punc = '''!()-[]{};:'"\, <>./?@#$%^&*_~ '''
    
    # Removing punctuations in string 
    # Using loop + punctuation string 
    for ele in test_str:  
        if ele in punc:  
            test_str = test_str.replace(ele, "")  

    # printing result  
    return test_str

# %%
def scraper(url = 'https://towardsdatascience.com', year = 2020):
    '''
    scrape all year content (10 posts/day)
    url: the url for the publishers on Medium
    '''

    # file storing
    name = get_name(url)
    name = f'./storage/{name}{year}.csv'
    print(f"File exists: {name}: " + str(path.exists(name)))

    if path.exists(name):
        return name

    # crawling
    ua = UserAgent()

    stories_data = []

    core_url = url

    # loop through the months
    for month in range(1, 13):
        num_days = calendar.monthrange(year, month)[1]

        month = str(month)

        if len(month) == 1:
            month = f'0{month}'

        # looping through the dates
        for day in range(1, num_days + 1):
            day = str(day)

            if len(day) == 1:
                day = f'0{day}'

            date = f'{day}/{month}/{year}'
            url = f'{core_url}/archive/{year}/{month}/{day}'
            print(url)

            headers = {'User-Agent': ua.random}
            
            # crawling with fake user agent
            page = requests.get(url, headers = headers)#, allow_redirects=False)
            soup = BeautifulSoup(page.text, 'html.parser')

            stories = soup.find_all('div', class_='streamItem streamItem--postPreview js-streamItem')
            if len(stories) > 10:
              stories = stories[:10]
              
            # extract keep information for each post
            for story in stories:
                each_story = []

                author_box = story.find('div', class_='postMetaInline u-floatLeft u-sm-maxWidthFullWidth')
                author_url = author_box.find('a')['href']

                try:
                    reading_time = author_box.find('span', class_='readingTime')['title']
                except:
                    continue

                title = story.find('h3').text if story.find('h3') else '-'

                subtitle = story.find('h4').text if story.find('h4') else '-'

                if story.find('button', class_='button button--chromeless u-baseColor--buttonNormal'
                                                ' js-multirecommendCountButton u-disablePointerEvents'):

                    claps = story.find('button', class_='button button--chromeless u-baseColor--buttonNormal'
                                                        ' js-multirecommendCountButton u-disablePointerEvents').text
                else:
                    claps = 0

                if story.find('a', class_='button button--chromeless u-baseColor--buttonNormal'):
                    responses = story.find('a', class_='button button--chromeless u-baseColor--buttonNormal').text
                else:
                    responses = '0 responses'

                story_url = story.find('a', class_='button button--smaller button--chromeless u-baseColor--buttonNormal')[
                    'href']

                reading_time = reading_time.split()[0]
                responses = responses.split()[0]

                story_page = requests.get(story_url)
                story_soup = BeautifulSoup(story_page.text, 'html.parser')

                sections = story_soup.find_all('section')
                story_paragraphs = []
                section_titles = []
                for section in sections:
                    paragraphs = section.find_all('p')
                    for paragraph in paragraphs:
                        story_paragraphs.append(paragraph.text)

                    subs = section.find_all('h1')
                    for sub in subs:
                        section_titles.append(sub.text)

                number_sections = len(section_titles)
                number_paragraphs = len(story_paragraphs)

                each_story.append(date)
                each_story.append(title)
                each_story.append(subtitle)
                each_story.append(claps)
                each_story.append(responses)
                each_story.append(author_url)
                each_story.append(story_url)
                each_story.append(reading_time)
                each_story.append(number_sections)
                each_story.append(section_titles)
                each_story.append(number_paragraphs)
                each_story.append(story_paragraphs)

                stories_data.append(each_story)

            print(f'{len(stories_data)} stories scraped so far.')

    # storing all in a .csv file
    columns = ['date', 'title', 'subtitle', 'claps', 'responses', 'author_url', 'story_url',
               'reading_time (mins)', 'number_sections', 'section_titles', 'number_paragraphs', 'paragraphs']

    df = pd.DataFrame(stories_data, columns=columns)

    df.to_csv(name, index=False)
    return name

# %%
url = 'https://towardsdatascience.com'
years = [2019, 2020]

# %%
# scraping for 2019 and 2020
for year in years:
  print(url, year)
  scraper(url, year)
  print("##################################################")
  print("")
# Out:
# https://towardsdatascience.com 2019
# File exists: ./storage/httpstowardsdatasciencecom2019.csv: False
# https://towardsdatascience.com/archive/2019/01/01
# 10 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/02
# 20 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/03
# 30 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/04
# 40 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/05
# 50 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/06
# 60 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/07
# 70 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/08
# 80 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/09
# 90 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/10
# 100 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/11
# 110 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/12
# 120 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/13
# 130 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/14
# 140 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/15
# 150 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/16
# 160 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/17
# 170 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/18
# 180 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/19
# 190 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/20
# 200 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/21
# 210 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/22
# 220 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/23
# 230 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/24
# 240 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/25
# 250 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/26
# 260 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/27
# 270 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/28
# 280 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/29
# 290 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/30
# 300 stories scraped so far.
# https://towardsdatascience.com/archive/2019/01/31
# 310 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/01
# 320 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/02
# 330 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/03
# 340 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/04
# 350 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/05
# 360 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/06
# 370 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/07
# 380 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/08
# 390 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/09
# 400 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/10
# 410 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/11
# 420 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/12
# 430 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/13
# 440 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/14
# 450 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/15
# 460 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/16
# 470 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/17
# 480 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/18
# 490 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/19
# 500 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/20
# 510 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/21
# 520 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/22
# 530 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/23
# 540 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/24
# 550 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/25
# 560 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/26
# 570 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/27
# 580 stories scraped so far.
# https://towardsdatascience.com/archive/2019/02/28
# 590 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/01
# 596 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/02
# 606 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/03
# 616 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/04
# 626 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/05
# 636 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/06
# 646 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/07
# 656 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/08
# 666 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/09
# 676 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/10
# 686 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/11
# 696 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/12
# 706 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/13
# 716 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/14
# 726 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/15
# 736 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/16
# 746 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/17
# 756 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/18
# 766 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/19
# 776 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/20
# 786 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/21
# 796 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/22
# 806 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/23
# 816 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/24
# 826 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/25
# 836 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/26
# 846 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/27
# 856 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/28
# 866 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/29
# 876 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/30
# 886 stories scraped so far.
# https://towardsdatascience.com/archive/2019/03/31
# 896 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/01
# 906 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/02
# 916 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/03
# 926 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/04
# 936 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/05
# 946 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/06
# 956 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/07
# 966 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/08
# 976 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/09
# 986 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/10
# 996 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/11
# 1006 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/12
# 1016 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/13
# 1025 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/14
# 1035 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/15
# 1045 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/16
# 1055 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/17
# 1065 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/18
# 1075 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/19
# 1085 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/20
# 1095 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/21
# 1105 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/22
# 1115 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/23
# 1125 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/24
# 1135 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/25
# 1145 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/26
# 1155 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/27
# 1165 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/28
# 1175 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/29
# 1185 stories scraped so far.
# https://towardsdatascience.com/archive/2019/04/30
# 1195 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/01
# 1205 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/02
# 1215 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/03
# 1225 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/04
# 1235 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/05
# 1245 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/06
# 1255 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/07
# 1265 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/08
# 1275 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/09
# 1285 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/10
# 1295 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/11
# 1305 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/12
# 1315 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/13
# 1325 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/14
# 1335 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/15
# 1345 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/16
# 1355 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/17
# 1365 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/18
# 1375 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/19
# 1385 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/20
# 1395 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/21
# 1405 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/22
# 1415 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/23
# 1425 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/24
# 1435 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/25
# 1445 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/26
# 1455 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/27
# 1465 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/28
# 1475 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/29
# 1485 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/30
# 1495 stories scraped so far.
# https://towardsdatascience.com/archive/2019/05/31
# 1505 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/01
# 1515 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/02
# 1525 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/03
# 1535 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/04
# 1545 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/05
# 1555 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/06
# 1565 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/07
# 1575 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/08
# 1585 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/09
# 1595 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/10
# 1605 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/11
# 1615 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/12
# 1625 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/13
# 1635 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/14
# 1645 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/15
# 1655 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/16
# 1665 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/17
# 1675 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/18
# 1685 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/19
# 1695 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/20
# 1705 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/21
# 1715 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/22
# 1725 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/23
# 1735 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/24
# 1745 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/25
# 1755 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/26
# 1765 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/27
# 1775 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/28
# 1785 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/29
# 1795 stories scraped so far.
# https://towardsdatascience.com/archive/2019/06/30
# 1805 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/01
# 1815 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/02
# 1825 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/03
# 1835 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/04
# 1845 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/05
# 1855 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/06
# 1865 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/07
# 1875 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/08
# 1885 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/09
# 1895 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/10
# 1895 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/11
# 1905 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/12
# 1915 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/13
# 1925 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/14
# 1935 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/15
# 1945 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/16
# 1955 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/17
# 1965 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/18
# 1975 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/19
# 1985 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/20
# 1995 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/21
# 2005 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/22
# 2015 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/23
# 2025 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/24
# 2035 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/25
# 2045 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/26
# 2055 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/27
# 2065 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/28
# 2075 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/29
# 2085 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/30
# 2095 stories scraped so far.
# https://towardsdatascience.com/archive/2019/07/31
# 2105 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/01
# 2115 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/02
# 2125 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/03
# 2135 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/04
# 2145 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/05
# 2155 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/06
# 2165 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/07
# 2175 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/08
# 2185 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/09
# 2195 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/10
# 2205 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/11
# 2215 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/12
# 2225 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/13
# 2235 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/14
# 2245 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/15
# 2255 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/16
# 2265 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/17
# 2275 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/18
# 2285 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/19
# 2295 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/20
# 2305 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/21
# 2315 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/22
# 2315 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/23
# 2325 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/24
# 2335 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/25
# 2345 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/26
# 2355 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/27
# 2365 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/28
# 2375 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/29
# 2385 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/30
# 2395 stories scraped so far.
# https://towardsdatascience.com/archive/2019/08/31
# 2405 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/01
# 2415 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/02
# 2425 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/03
# 2435 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/04
# 2445 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/05
# 2455 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/06
# 2465 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/07
# 2475 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/08
# 2485 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/09
# 2495 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/10
# 2505 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/11
# 2515 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/12
# 2525 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/13
# 2535 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/14
# 2545 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/15
# 2555 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/16
# 2565 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/17
# 2575 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/18
# 2585 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/19
# 2595 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/20
# 2605 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/21
# 2615 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/22
# 2625 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/23
# 2635 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/24
# 2645 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/25
# 2655 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/26
# 2665 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/27
# 2675 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/28
# 2685 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/29
# 2695 stories scraped so far.
# https://towardsdatascience.com/archive/2019/09/30
# 2695 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/01
# 2705 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/02
# 2715 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/03
# 2725 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/04
# 2735 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/05
# 2745 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/06
# 2755 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/07
# 2765 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/08
# 2775 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/09
# 2785 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/10
# 2795 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/11
# 2805 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/12
# 2815 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/13
# 2825 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/14
# 2835 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/15
# 2845 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/16
# 2855 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/17
# 2865 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/18
# 2875 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/19
# 2885 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/20
# 2895 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/21
# 2905 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/22
# 2915 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/23
# 2925 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/24
# 2935 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/25
# 2945 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/26
# 2955 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/27
# 2965 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/28
# 2975 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/29
# 2985 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/30
# 2995 stories scraped so far.
# https://towardsdatascience.com/archive/2019/10/31
# 3005 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/01
# 3015 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/02
# 3025 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/03
# 3035 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/04
# 3045 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/05
# 3055 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/06
# 3065 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/07
# 3075 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/08
# 3085 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/09
# 3095 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/10
# 3105 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/11
# 3115 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/12
# 3125 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/13
# 3135 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/14
# 3145 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/15
# 3155 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/16
# 3165 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/17
# 3175 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/18
# 3185 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/19
# 3195 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/20
# 3205 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/21
# 3215 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/22
# 3225 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/23
# 3235 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/24
# 3245 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/25
# 3255 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/26
# 3265 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/27
# 3275 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/28
# 3285 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/29
# 3295 stories scraped so far.
# https://towardsdatascience.com/archive/2019/11/30
# 3305 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/01
# 3315 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/02
# 3325 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/03
# 3335 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/04
# 3345 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/05
# 3355 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/06
# 3365 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/07
# 3375 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/08
# 3385 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/09
# 3395 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/10
# 3405 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/11
# 3415 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/12
# 3425 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/13
# 3435 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/14
# 3445 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/15
# 3455 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/16
# 3465 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/17
# 3475 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/18
# 3485 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/19
# 3495 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/20
# 3505 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/21
# 3515 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/22
# 3525 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/23
# 3535 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/24
# 3545 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/25
# 3555 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/26
# 3565 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/27
# 3575 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/28
# 3585 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/29
# 3595 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/30
# 3605 stories scraped so far.
# https://towardsdatascience.com/archive/2019/12/31
# 3615 stories scraped so far.
# ##################################################
#
# https://towardsdatascience.com 2020
# File exists: ./storage/httpstowardsdatasciencecom2020.csv: False
# https://towardsdatascience.com/archive/2020/01/01
# 10 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/02
# 20 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/03
# 30 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/04
# 40 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/05
# 50 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/06
# 60 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/07
# 70 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/08
# 80 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/09
# 90 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/10
# 100 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/11
# 110 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/12
# 120 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/13
# 130 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/14
# 140 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/15
# 150 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/16
# 160 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/17
# 170 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/18
# 180 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/19
# 190 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/20
# 200 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/21
# 210 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/22
# 220 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/23
# 230 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/24
# 240 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/25
# 250 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/26
# 260 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/27
# 270 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/28
# 280 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/29
# 290 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/30
# 300 stories scraped so far.
# https://towardsdatascience.com/archive/2020/01/31
# 310 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/01
# 320 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/02
# 330 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/03
# 340 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/04
# 350 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/05
# 360 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/06
# 370 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/07
# 380 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/08
# 390 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/09
# 400 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/10
# 410 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/11
# 420 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/12
# 430 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/13
# 440 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/14
# 450 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/15
# 460 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/16
# 470 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/17
# 480 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/18
# 490 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/19
# 500 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/20
# 510 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/21
# 520 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/22
# 530 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/23
# 540 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/24
# 550 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/25
# 560 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/26
# 570 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/27
# 580 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/28
# 590 stories scraped so far.
# https://towardsdatascience.com/archive/2020/02/29
# 600 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/01
# 610 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/02
# 620 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/03
# 630 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/04
# 640 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/05
# 650 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/06
# 660 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/07
# 670 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/08
# 680 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/09
# 690 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/10
# 700 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/11
# 710 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/12
# 720 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/13
# 730 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/14
# 740 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/15
# 740 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/16
# 750 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/17
# 760 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/18
# 770 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/19
# 780 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/20
# 790 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/21
# 800 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/22
# 810 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/23
# 820 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/24
# 830 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/25
# 840 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/26
# 850 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/27
# 860 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/28
# 870 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/29
# 880 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/30
# 890 stories scraped so far.
# https://towardsdatascience.com/archive/2020/03/31
# 900 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/01
# 910 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/02
# 920 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/03
# 930 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/04
# 940 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/05
# 950 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/06
# 960 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/07
# 970 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/08
# 980 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/09
# 990 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/10
# 1000 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/11
# 1010 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/12
# 1020 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/13
# 1030 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/14
# 1040 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/15
# 1050 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/16
# 1060 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/17
# 1070 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/18
# 1080 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/19
# 1090 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/20
# 1100 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/21
# 1110 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/22
# 1120 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/23
# 1130 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/24
# 1140 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/25
# 1150 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/26
# 1160 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/27
# 1170 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/28
# 1180 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/29
# 1190 stories scraped so far.
# https://towardsdatascience.com/archive/2020/04/30
# 1200 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/01
# 1210 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/02
# 1220 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/03
# 1230 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/04
# 1240 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/05
# 1250 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/06
# 1260 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/07
# 1270 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/08
# 1280 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/09
# 1290 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/10
# 1300 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/11
# 1310 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/12
# 1320 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/13
# 1330 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/14
# 1340 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/15
# 1350 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/16
# 1360 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/17
# 1370 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/18
# 1380 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/19
# 1390 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/20
# 1400 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/21
# 1410 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/22
# 1420 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/23
# 1430 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/24
# 1440 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/25
# 1450 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/26
# 1460 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/27
# 1470 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/28
# 1480 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/29
# 1490 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/30
# 1500 stories scraped so far.
# https://towardsdatascience.com/archive/2020/05/31
# 1510 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/01
# 1520 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/02
# 1530 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/03
# 1540 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/04
# 1550 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/05
# 1560 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/06
# 1570 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/07
# 1580 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/08
# 1590 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/09
# 1600 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/10
# 1610 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/11
# 1620 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/12
# 1630 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/13
# 1640 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/14
# 1650 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/15
# 1660 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/16
# 1670 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/17
# 1680 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/18
# 1690 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/19
# 1700 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/20
# 1710 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/21
# 1720 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/22
# 1730 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/23
# 1740 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/24
# 1750 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/25
# 1760 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/26
# 1770 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/27
# 1780 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/28
# 1790 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/29
# 1800 stories scraped so far.
# https://towardsdatascience.com/archive/2020/06/30
# 1810 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/01
# 1820 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/02
# 1830 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/03
# 1840 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/04
# 1850 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/05
# 1860 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/06
# 1870 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/07
# 1880 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/08
# 1890 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/09
# 1900 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/10
# 1910 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/11
# 1920 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/12
# 1930 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/13
# 1940 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/14
# 1950 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/15
# 1960 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/16
# 1970 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/17
# 1980 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/18
# 1990 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/19
# 2000 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/20
# 2010 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/21
# 2020 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/22
# 2030 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/23
# 2040 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/24
# 2050 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/25
# 2060 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/26
# 2070 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/27
# 2080 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/28
# 2090 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/29
# 2100 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/30
# 2110 stories scraped so far.
# https://towardsdatascience.com/archive/2020/07/31
# 2120 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/01
# 2130 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/02
# 2140 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/03
# 2150 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/04
# 2160 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/05
# 2170 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/06
# 2180 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/07
# 2190 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/08
# 2200 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/09
# 2210 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/10
# 2220 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/11
# 2230 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/12
# 2240 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/13
# 2250 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/14
# 2260 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/15
# 2270 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/16
# 2280 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/17
# 2290 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/18
# 2300 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/19
# 2310 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/20
# 2320 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/21
# 2330 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/22
# 2340 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/23
# 2350 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/24
# 2360 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/25
# 2370 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/26
# 2380 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/27
# 2390 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/28
# 2400 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/29
# 2410 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/30
# 2420 stories scraped so far.
# https://towardsdatascience.com/archive/2020/08/31
# 2430 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/01
# 2440 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/02
# 2450 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/03
# 2460 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/04
# 2470 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/05
# 2480 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/06
# 2490 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/07
# 2500 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/08
# 2510 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/09
# 2520 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/10
# 2530 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/11
# 2540 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/12
# 2550 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/13
# 2560 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/14
# 2570 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/15
# 2580 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/16
# 2590 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/17
# 2600 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/18
# 2610 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/19
# 2620 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/20
# 2630 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/21
# 2640 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/22
# 2650 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/23
# 2660 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/24
# 2670 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/25
# 2680 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/26
# 2690 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/27
# 2700 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/28
# 2710 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/29
# 2720 stories scraped so far.
# https://towardsdatascience.com/archive/2020/09/30
# 2730 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/01
# 2740 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/02
# 2750 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/03
# 2760 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/04
# 2770 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/05
# 2780 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/06
# 2790 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/07
# 2800 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/08
# 2810 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/09
# 2820 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/10
# 2830 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/11
# 2840 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/12
# 2850 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/13
# 2860 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/14
# 2870 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/15
# 2880 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/16
# 2890 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/17
# 2900 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/18
# 2910 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/19
# 2920 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/20
# 2930 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/21
# 2940 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/22
# 2950 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/23
# 2960 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/24
# 2970 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/25
# 2980 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/26
# 2990 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/27
# 3000 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/28
# 3010 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/29
# 3020 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/30
# 3030 stories scraped so far.
# https://towardsdatascience.com/archive/2020/10/31
# 3040 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/01
# 3050 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/02
# 3060 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/03
# 3070 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/04
# 3080 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/05
# 3090 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/06
# 3100 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/07
# 3110 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/08
# 3120 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/09
# 3130 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/10
# 3140 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/11
# 3150 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/12
# 3160 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/13
# 3170 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/14
# 3179 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/15
# 3189 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/16
# 3199 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/17
# 3209 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/18
# 3219 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/19
# 3229 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/20
# 3239 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/21
# 3249 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/22
# 3259 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/23
# 3269 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/24
# 3279 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/25
# 3289 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/26
# 3299 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/27
# 3309 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/28
# 3319 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/29
# 3329 stories scraped so far.
# https://towardsdatascience.com/archive/2020/11/30
# 3339 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/01
# 3349 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/02
# 3359 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/03
# 3369 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/04
# 3379 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/05
# 3389 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/06
# 3399 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/07
# 3409 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/08
# 3419 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/09
# 3429 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/10
# 3439 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/11
# 3449 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/12
# 3459 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/13
# 3469 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/14
# 3479 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/15
# 3489 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/16
# 3499 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/17
# 3509 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/18
# 3519 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/19
# 3529 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/20
# 3539 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/21
# 3549 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/22
# 3559 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/23
# 3569 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/24
# 3579 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/25
# 3589 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/26
# 3599 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/27
# 3609 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/28
# 3619 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/29
# 3629 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/30
# 3639 stories scraped so far.
# https://towardsdatascience.com/archive/2020/12/31
# 3649 stories scraped so far.
# ##################################################
